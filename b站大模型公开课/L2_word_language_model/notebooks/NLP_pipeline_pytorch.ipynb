# %% [markdown]
# ### Dataset
# data目录下有两种数据集:
#
# glue-sst2: 给定一个句子判定这个句子的情感, 是positive和negative
#
# wikitext: wiki百科优质文章

# %% [markdown]
# ### wikitext in LSTM

# %%
# 代码上传到了google drive，需要挂载并cd到指定目录
from google.colab import drive
drive.mount('/content/drive')
import os

# %cd /content/drive/MyDrive/nlp-project/word_language_model/
# %ll
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/nlp-project/word_language_model
# total 55258
# drwx------ 2 root     4096 Jan  7 13:44 data/
# -rw------- 1 root     2829 Jan 14 03:41 data.py
# -rw------- 1 root   600536 Jan 14 10:51 id_mapping.pkl
# -rw------- 1 root    10439 Jan 14 10:51 main.py
# -rw------- 1 root 55955216 Jan 14 03:58 model.pt
# -rw------- 1 root     2839 Jul 15  2022 model.py
# drwx------ 2 root     4096 Jan  7 14:05 __pycache__/
# -rw------- 1 root     2094 Jul 15  2022 README.md

# %% [markdown]
# #### 训练

# %%
# 使用默认参数
# %pwd
# !python main.py --data './data/wikitext' --cuda --epochs 20
# Out:
# ./data/wikitext/train.txt
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 13.79 | loss  7.64 | ppl  2070.90
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  6.86 | ppl   950.48
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch  7.71 | loss  6.49 | ppl   661.52
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  6.30 | ppl   546.19
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.71 | loss  6.15 | ppl   468.81
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  6.07 | ppl   431.42
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  5.96 | ppl   387.33
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  5.96 | ppl   386.70
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.81 | ppl   332.83
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.78 | ppl   325.12
# | epoch   1 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  5.67 | ppl   290.28
# | epoch   1 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  5.68 | ppl   291.72
# | epoch   1 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.67 | ppl   288.88
# | epoch   1 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.55 | ppl   258.01
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 25.38s | valid loss  5.59 | valid ppl   268.89
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2983 batches | lr 20.00 | ms/batch  7.86 | loss  5.55 | ppl   258.46
# | epoch   2 |   400/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.54 | ppl   253.91
# | epoch   2 |   600/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  5.37 | ppl   215.84
# | epoch   2 |   800/ 2983 batches | lr 20.00 | ms/batch  7.81 | loss  5.39 | ppl   219.29
# | epoch   2 |  1000/ 2983 batches | lr 20.00 | ms/batch  8.30 | loss  5.36 | ppl   212.02
# | epoch   2 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.34 | ppl   207.91
# | epoch   2 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.94 | loss  5.33 | ppl   207.34
# | epoch   2 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.39 | ppl   219.34
# | epoch   2 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.26 | ppl   192.33
# | epoch   2 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.27 | ppl   195.30
# | epoch   2 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  5.18 | ppl   177.85
# | epoch   2 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.21 | ppl   183.14
# | epoch   2 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.22 | ppl   185.75
# | epoch   2 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  5.13 | ppl   169.72
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 24.36s | valid loss  5.38 | valid ppl   216.26
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2983 batches | lr 20.00 | ms/batch  7.85 | loss  5.19 | ppl   180.02
# | epoch   3 |   400/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.21 | ppl   182.64
# | epoch   3 |   600/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.02 | ppl   152.15
# | epoch   3 |   800/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  5.07 | ppl   158.98
# | epoch   3 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.05 | ppl   156.72
# | epoch   3 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.05 | ppl   156.52
# | epoch   3 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  5.08 | ppl   159.99
# | epoch   3 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.15 | ppl   171.74
# | epoch   3 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  5.01 | ppl   150.50
# | epoch   3 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  5.04 | ppl   154.61
# | epoch   3 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.95 | ppl   141.09
# | epoch   3 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.98 | ppl   145.90
# | epoch   3 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.81 | loss  5.00 | ppl   149.14
# | epoch   3 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  4.93 | ppl   137.97
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 24.25s | valid loss  5.20 | valid ppl   180.80
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/ 2983 batches | lr 20.00 | ms/batch  7.83 | loss  5.00 | ppl   148.62
# | epoch   4 |   400/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  5.02 | ppl   151.36
# | epoch   4 |   600/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.84 | ppl   126.55
# | epoch   4 |   800/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.89 | ppl   133.31
# | epoch   4 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.88 | ppl   132.28
# | epoch   4 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.89 | ppl   132.75
# | epoch   4 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.93 | ppl   137.97
# | epoch   4 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  5.00 | ppl   148.20
# | epoch   4 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.87 | ppl   130.21
# | epoch   4 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.90 | ppl   133.69
# | epoch   4 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.81 | ppl   122.72
# | epoch   4 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.85 | ppl   127.14
# | epoch   4 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.87 | ppl   129.87
# | epoch   4 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.80 | ppl   121.25
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 24.22s | valid loss  5.12 | valid ppl   166.97
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/ 2983 batches | lr 20.00 | ms/batch  7.80 | loss  4.87 | ppl   130.43
# | epoch   5 |   400/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.89 | ppl   133.26
# | epoch   5 |   600/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  4.72 | ppl   111.70
# | epoch   5 |   800/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.78 | ppl   118.87
# | epoch   5 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.77 | ppl   118.38
# | epoch   5 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  4.78 | ppl   118.97
# | epoch   5 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.82 | ppl   123.86
# | epoch   5 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.89 | ppl   133.46
# | epoch   5 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.77 | ppl   117.40
# | epoch   5 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.80 | ppl   121.42
# | epoch   5 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.70 | ppl   109.70
# | epoch   5 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.74 | ppl   114.71
# | epoch   5 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.77 | ppl   118.20
# | epoch   5 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.70 | ppl   110.15
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 24.15s | valid loss  5.06 | valid ppl   157.54
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/ 2983 batches | lr 20.00 | ms/batch  7.80 | loss  4.77 | ppl   118.11
# | epoch   6 |   400/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.80 | ppl   121.50
# | epoch   6 |   600/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.62 | ppl   101.59
# | epoch   6 |   800/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.68 | ppl   107.68
# | epoch   6 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.71 | loss  4.68 | ppl   108.05
# | epoch   6 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.80 | loss  4.69 | ppl   108.62
# | epoch   6 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.81 | loss  4.74 | ppl   113.99
# | epoch   6 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.81 | ppl   122.60
# | epoch   6 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  4.69 | ppl   108.73
# | epoch   6 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.72 | ppl   112.18
# | epoch   6 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.62 | ppl   101.56
# | epoch   6 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.66 | ppl   105.72
# | epoch   6 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.69 | ppl   109.01
# | epoch   6 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.63 | ppl   102.13
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 24.21s | valid loss  5.01 | valid ppl   150.61
# -----------------------------------------------------------------------------------------
# | epoch   7 |   200/ 2983 batches | lr 20.00 | ms/batch  7.87 | loss  4.69 | ppl   109.18
# | epoch   7 |   400/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.72 | ppl   111.98
# | epoch   7 |   600/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.55 | ppl    94.43
# | epoch   7 |   800/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.60 | ppl    99.79
# | epoch   7 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.62 | ppl   101.01
# | epoch   7 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.62 | ppl   101.53
# | epoch   7 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.67 | ppl   106.91
# | epoch   7 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.75 | ppl   115.15
# | epoch   7 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  4.62 | ppl   101.65
# | epoch   7 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.66 | ppl   105.15
# | epoch   7 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.56 | ppl    95.12
# | epoch   7 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.81 | loss  4.60 | ppl    99.41
# | epoch   7 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  4.63 | ppl   102.62
# | epoch   7 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  4.56 | ppl    95.79
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 24.21s | valid loss  5.00 | valid ppl   148.31
# -----------------------------------------------------------------------------------------
# | epoch   8 |   200/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  4.63 | ppl   102.61
# | epoch   8 |   400/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.66 | ppl   105.50
# | epoch   8 |   600/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.49 | ppl    88.75
# | epoch   8 |   800/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.54 | ppl    93.60
# | epoch   8 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.56 | ppl    95.24
# | epoch   8 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  4.57 | ppl    96.45
# | epoch   8 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.61 | ppl   100.83
# | epoch   8 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.69 | ppl   108.45
# | epoch   8 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.57 | ppl    96.49
# | epoch   8 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.61 | ppl    99.99
# | epoch   8 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.50 | ppl    90.29
# | epoch   8 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.55 | ppl    94.33
# | epoch   8 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.72 | loss  4.58 | ppl    97.59
# | epoch   8 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.51 | ppl    91.28
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 24.15s | valid loss  4.99 | valid ppl   146.95
# -----------------------------------------------------------------------------------------
# | epoch   9 |   200/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.58 | ppl    97.62
# | epoch   9 |   400/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.61 | ppl   100.72
# | epoch   9 |   600/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.43 | ppl    84.18
# | epoch   9 |   800/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.49 | ppl    89.23
# | epoch   9 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.51 | ppl    91.14
# | epoch   9 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.51 | ppl    91.36
# | epoch   9 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.83 | loss  4.57 | ppl    96.08
# | epoch   9 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.64 | ppl   103.45
# | epoch   9 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.53 | ppl    92.68
# | epoch   9 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.56 | ppl    95.76
# | epoch   9 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.45 | ppl    85.84
# | epoch   9 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.50 | ppl    89.78
# | epoch   9 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.53 | ppl    92.73
# | epoch   9 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.74 | loss  4.47 | ppl    87.39
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 24.18s | valid loss  4.97 | valid ppl   144.43
# -----------------------------------------------------------------------------------------
# | epoch  10 |   200/ 2983 batches | lr 20.00 | ms/batch  7.81 | loss  4.53 | ppl    93.00
# | epoch  10 |   400/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.56 | ppl    95.52
# | epoch  10 |   600/ 2983 batches | lr 20.00 | ms/batch  7.73 | loss  4.39 | ppl    80.86
# | epoch  10 |   800/ 2983 batches | lr 20.00 | ms/batch  7.77 | loss  4.45 | ppl    85.52
# | epoch  10 |  1000/ 2983 batches | lr 20.00 | ms/batch  7.80 | loss  4.47 | ppl    87.04
# | epoch  10 |  1200/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.48 | ppl    88.22
# | epoch  10 |  1400/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.53 | ppl    92.39
# | epoch  10 |  1600/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.61 | ppl   100.15
# | epoch  10 |  1800/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.49 | ppl    88.99
# | epoch  10 |  2000/ 2983 batches | lr 20.00 | ms/batch  7.75 | loss  4.52 | ppl    92.17
# | epoch  10 |  2200/ 2983 batches | lr 20.00 | ms/batch  7.76 | loss  4.41 | ppl    82.63
# | epoch  10 |  2400/ 2983 batches | lr 20.00 | ms/batch  7.78 | loss  4.46 | ppl    86.44
# | epoch  10 |  2600/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  4.49 | ppl    89.48
# | epoch  10 |  2800/ 2983 batches | lr 20.00 | ms/batch  7.79 | loss  4.43 | ppl    84.34
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 24.18s | valid loss  4.98 | valid ppl   145.78
# -----------------------------------------------------------------------------------------
# | epoch  11 |   200/ 2983 batches | lr 5.00 | ms/batch  7.78 | loss  4.54 | ppl    93.76
# | epoch  11 |   400/ 2983 batches | lr 5.00 | ms/batch  7.75 | loss  4.54 | ppl    93.30
# | epoch  11 |   600/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.36 | ppl    78.02
# | epoch  11 |   800/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.39 | ppl    80.95
# | epoch  11 |  1000/ 2983 batches | lr 5.00 | ms/batch  7.77 | loss  4.38 | ppl    80.19
# | epoch  11 |  1200/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.38 | ppl    79.61
# | epoch  11 |  1400/ 2983 batches | lr 5.00 | ms/batch  7.78 | loss  4.40 | ppl    81.79
# | epoch  11 |  1600/ 2983 batches | lr 5.00 | ms/batch  7.71 | loss  4.46 | ppl    86.59
# | epoch  11 |  1800/ 2983 batches | lr 5.00 | ms/batch  7.71 | loss  4.33 | ppl    76.25
# | epoch  11 |  2000/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.35 | ppl    77.77
# | epoch  11 |  2200/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.23 | ppl    68.77
# | epoch  11 |  2400/ 2983 batches | lr 5.00 | ms/batch  7.75 | loss  4.25 | ppl    70.14
# | epoch  11 |  2600/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.27 | ppl    71.80
# | epoch  11 |  2800/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.19 | ppl    66.29
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 24.12s | valid loss  4.83 | valid ppl   125.65
# -----------------------------------------------------------------------------------------
# | epoch  12 |   200/ 2983 batches | lr 5.00 | ms/batch  7.79 | loss  4.39 | ppl    80.47
# | epoch  12 |   400/ 2983 batches | lr 5.00 | ms/batch  7.75 | loss  4.41 | ppl    82.29
# | epoch  12 |   600/ 2983 batches | lr 5.00 | ms/batch  7.77 | loss  4.24 | ppl    69.18
# | epoch  12 |   800/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.29 | ppl    72.67
# | epoch  12 |  1000/ 2983 batches | lr 5.00 | ms/batch  7.82 | loss  4.30 | ppl    73.45
# | epoch  12 |  1200/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.30 | ppl    73.69
# | epoch  12 |  1400/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.33 | ppl    75.90
# | epoch  12 |  1600/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.40 | ppl    81.08
# | epoch  12 |  1800/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.27 | ppl    71.76
# | epoch  12 |  2000/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.30 | ppl    74.05
# | epoch  12 |  2200/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.19 | ppl    65.83
# | epoch  12 |  2400/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.21 | ppl    67.31
# | epoch  12 |  2600/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.25 | ppl    69.98
# | epoch  12 |  2800/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.17 | ppl    65.01
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 24.16s | valid loss  4.82 | valid ppl   124.55
# -----------------------------------------------------------------------------------------
# | epoch  13 |   200/ 2983 batches | lr 5.00 | ms/batch  7.79 | loss  4.34 | ppl    76.46
# | epoch  13 |   400/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.36 | ppl    78.06
# | epoch  13 |   600/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.18 | ppl    65.62
# | epoch  13 |   800/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.23 | ppl    68.81
# | epoch  13 |  1000/ 2983 batches | lr 5.00 | ms/batch  7.71 | loss  4.25 | ppl    70.31
# | epoch  13 |  1200/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.26 | ppl    70.82
# | epoch  13 |  1400/ 2983 batches | lr 5.00 | ms/batch  7.78 | loss  4.30 | ppl    73.38
# | epoch  13 |  1600/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.36 | ppl    78.12
# | epoch  13 |  1800/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.24 | ppl    69.54
# | epoch  13 |  2000/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.27 | ppl    71.55
# | epoch  13 |  2200/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.16 | ppl    63.98
# | epoch  13 |  2400/ 2983 batches | lr 5.00 | ms/batch  7.72 | loss  4.18 | ppl    65.35
# | epoch  13 |  2600/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.22 | ppl    68.32
# | epoch  13 |  2800/ 2983 batches | lr 5.00 | ms/batch  7.74 | loss  4.15 | ppl    63.70
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 24.12s | valid loss  4.81 | valid ppl   123.12
# -----------------------------------------------------------------------------------------
# | epoch  14 |   200/ 2983 batches | lr 5.00 | ms/batch  7.85 | loss  4.30 | ppl    73.57
# | epoch  14 |   400/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.32 | ppl    75.35
# | epoch  14 |   600/ 2983 batches | lr 5.00 | ms/batch  7.71 | loss  4.15 | ppl    63.68
# | epoch  14 |   800/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.20 | ppl    66.67
# | epoch  14 |  1000/ 2983 batches | lr 5.00 | ms/batch  7.75 | loss  4.22 | ppl    68.03
# | epoch  14 |  1200/ 2983 batches | lr 5.00 | ms/batch  7.73 | loss  4.23 | ppl    68.70
# | epoch  14 |  1400/ 2983 batches | lr 5.00 | ms/batch  7.80 | loss  4.26 | ppl    71.04
# | epoch  14 |  1600/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.33 | ppl    76.26
# | epoch  14 |  1800/ 2983 batches | lr 5.00 | ms/batch  7.84 | loss  4.22 | ppl    68.01
# | epoch  14 |  2000/ 2983 batches | lr 5.00 | ms/batch  7.81 | loss  4.25 | ppl    70.25
# | epoch  14 |  2200/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.13 | ppl    62.46
# | epoch  14 |  2400/ 2983 batches | lr 5.00 | ms/batch  7.78 | loss  4.16 | ppl    64.03
# | epoch  14 |  2600/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.20 | ppl    67.00
# | epoch  14 |  2800/ 2983 batches | lr 5.00 | ms/batch  7.76 | loss  4.14 | ppl    62.53
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 24.25s | valid loss  4.82 | valid ppl   123.55
# -----------------------------------------------------------------------------------------
# | epoch  15 |   200/ 2983 batches | lr 1.25 | ms/batch  7.85 | loss  4.31 | ppl    74.22
# | epoch  15 |   400/ 2983 batches | lr 1.25 | ms/batch  7.78 | loss  4.35 | ppl    77.20
# | epoch  15 |   600/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.18 | ppl    65.38
# | epoch  15 |   800/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.24 | ppl    69.45
# | epoch  15 |  1000/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.23 | ppl    68.42
# | epoch  15 |  1200/ 2983 batches | lr 1.25 | ms/batch  7.78 | loss  4.23 | ppl    68.68
# | epoch  15 |  1400/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.26 | ppl    71.16
# | epoch  15 |  1600/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.32 | ppl    75.45
# | epoch  15 |  1800/ 2983 batches | lr 1.25 | ms/batch  7.79 | loss  4.21 | ppl    67.05
# | epoch  15 |  2000/ 2983 batches | lr 1.25 | ms/batch  7.80 | loss  4.22 | ppl    68.00
# | epoch  15 |  2200/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.10 | ppl    60.43
# | epoch  15 |  2400/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.13 | ppl    62.09
# | epoch  15 |  2600/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.16 | ppl    63.89
# | epoch  15 |  2800/ 2983 batches | lr 1.25 | ms/batch  7.78 | loss  4.08 | ppl    59.05
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 24.21s | valid loss  4.78 | valid ppl   118.67
# -----------------------------------------------------------------------------------------
# | epoch  16 |   200/ 2983 batches | lr 1.25 | ms/batch  7.81 | loss  4.28 | ppl    72.46
# | epoch  16 |   400/ 2983 batches | lr 1.25 | ms/batch  7.78 | loss  4.30 | ppl    73.74
# | epoch  16 |   600/ 2983 batches | lr 1.25 | ms/batch  7.79 | loss  4.14 | ppl    62.77
# | epoch  16 |   800/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.20 | ppl    66.52
# | epoch  16 |  1000/ 2983 batches | lr 1.25 | ms/batch  7.79 | loss  4.19 | ppl    66.07
# | epoch  16 |  1200/ 2983 batches | lr 1.25 | ms/batch  7.78 | loss  4.20 | ppl    66.83
# | epoch  16 |  1400/ 2983 batches | lr 1.25 | ms/batch  7.82 | loss  4.24 | ppl    69.58
# | epoch  16 |  1600/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.30 | ppl    73.46
# | epoch  16 |  1800/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.19 | ppl    65.80
# | epoch  16 |  2000/ 2983 batches | lr 1.25 | ms/batch  7.79 | loss  4.20 | ppl    66.97
# | epoch  16 |  2200/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.10 | ppl    60.04
# | epoch  16 |  2400/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.12 | ppl    61.43
# | epoch  16 |  2600/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.16 | ppl    63.85
# | epoch  16 |  2800/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.08 | ppl    58.92
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 24.21s | valid loss  4.77 | valid ppl   118.04
# -----------------------------------------------------------------------------------------
# | epoch  17 |   200/ 2983 batches | lr 1.25 | ms/batch  7.76 | loss  4.27 | ppl    71.17
# | epoch  17 |   400/ 2983 batches | lr 1.25 | ms/batch  7.76 | loss  4.29 | ppl    72.73
# | epoch  17 |   600/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.13 | ppl    62.06
# | epoch  17 |   800/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.18 | ppl    65.38
# | epoch  17 |  1000/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.18 | ppl    65.05
# | epoch  17 |  1200/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.19 | ppl    65.72
# | epoch  17 |  1400/ 2983 batches | lr 1.25 | ms/batch  7.84 | loss  4.23 | ppl    68.63
# | epoch  17 |  1600/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.29 | ppl    72.73
# | epoch  17 |  1800/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.17 | ppl    64.73
# | epoch  17 |  2000/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.20 | ppl    66.52
# | epoch  17 |  2200/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.08 | ppl    59.41
# | epoch  17 |  2400/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.11 | ppl    61.03
# | epoch  17 |  2600/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.15 | ppl    63.26
# | epoch  17 |  2800/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.08 | ppl    59.05
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 24.16s | valid loss  4.77 | valid ppl   117.96
# -----------------------------------------------------------------------------------------
# | epoch  18 |   200/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.25 | ppl    70.28
# | epoch  18 |   400/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.27 | ppl    71.72
# | epoch  18 |   600/ 2983 batches | lr 1.25 | ms/batch  7.71 | loss  4.11 | ppl    61.00
# | epoch  18 |   800/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.16 | ppl    64.23
# | epoch  18 |  1000/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.17 | ppl    64.45
# | epoch  18 |  1200/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.18 | ppl    65.07
# | epoch  18 |  1400/ 2983 batches | lr 1.25 | ms/batch  7.76 | loss  4.22 | ppl    68.15
# | epoch  18 |  1600/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.28 | ppl    71.95
# | epoch  18 |  1800/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.16 | ppl    64.21
# | epoch  18 |  2000/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.19 | ppl    65.97
# | epoch  18 |  2200/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.08 | ppl    59.07
# | epoch  18 |  2400/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.11 | ppl    60.76
# | epoch  18 |  2600/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.14 | ppl    62.92
# | epoch  18 |  2800/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.07 | ppl    58.44
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 24.13s | valid loss  4.77 | valid ppl   117.64
# -----------------------------------------------------------------------------------------
# | epoch  19 |   200/ 2983 batches | lr 1.25 | ms/batch  7.79 | loss  4.24 | ppl    69.37
# | epoch  19 |   400/ 2983 batches | lr 1.25 | ms/batch  7.71 | loss  4.26 | ppl    71.13
# | epoch  19 |   600/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.10 | ppl    60.45
# | epoch  19 |   800/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.16 | ppl    63.95
# | epoch  19 |  1000/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.17 | ppl    64.48
# | epoch  19 |  1200/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.16 | ppl    64.36
# | epoch  19 |  1400/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.21 | ppl    67.37
# | epoch  19 |  1600/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.27 | ppl    71.41
# | epoch  19 |  1800/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.16 | ppl    64.02
# | epoch  19 |  2000/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.18 | ppl    65.68
# | epoch  19 |  2200/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.07 | ppl    58.48
# | epoch  19 |  2400/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.10 | ppl    60.35
# | epoch  19 |  2600/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.14 | ppl    62.52
# | epoch  19 |  2800/ 2983 batches | lr 1.25 | ms/batch  7.71 | loss  4.07 | ppl    58.50
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 24.08s | valid loss  4.77 | valid ppl   117.46
# -----------------------------------------------------------------------------------------
# | epoch  20 |   200/ 2983 batches | lr 1.25 | ms/batch  7.77 | loss  4.23 | ppl    68.53
# | epoch  20 |   400/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.25 | ppl    70.20
# | epoch  20 |   600/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.09 | ppl    59.80
# | epoch  20 |   800/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.14 | ppl    62.91
# | epoch  20 |  1000/ 2983 batches | lr 1.25 | ms/batch  7.72 | loss  4.15 | ppl    63.32
# | epoch  20 |  1200/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.16 | ppl    64.04
# | epoch  20 |  1400/ 2983 batches | lr 1.25 | ms/batch  7.82 | loss  4.20 | ppl    66.82
# | epoch  20 |  1600/ 2983 batches | lr 1.25 | ms/batch  7.76 | loss  4.26 | ppl    70.63
# | epoch  20 |  1800/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.15 | ppl    63.18
# | epoch  20 |  2000/ 2983 batches | lr 1.25 | ms/batch  7.75 | loss  4.18 | ppl    65.27
# | epoch  20 |  2200/ 2983 batches | lr 1.25 | ms/batch  7.76 | loss  4.06 | ppl    58.26
# | epoch  20 |  2400/ 2983 batches | lr 1.25 | ms/batch  7.74 | loss  4.09 | ppl    60.00
# | epoch  20 |  2600/ 2983 batches | lr 1.25 | ms/batch  7.76 | loss  4.14 | ppl    62.52
# | epoch  20 |  2800/ 2983 batches | lr 1.25 | ms/batch  7.73 | loss  4.06 | ppl    57.91
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 24.13s | valid loss  4.77 | valid ppl   117.34
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training | test loss  4.71 | test ppl   110.75
# =========================================================================================

# %% [markdown]
# #### 测试模型的效果

# %%
# 挂载磁盘
# 代码上传到了google drive，需要挂载并cd到指定目录
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/nlp-project/word_language_model/
# %ll
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/nlp-project/word_language_model
# total 55258
# drwx------ 2 root     4096 Jan  7 13:44 data/
# -rw------- 1 root     2829 Jan 14 03:41 data.py
# -rw------- 1 root   600536 Jan 14 10:53 id_mapping.pkl
# -rw------- 1 root    10439 Jan 14 10:51 main.py
# -rw------- 1 root 55955216 Jan 14 11:01 model.pt
# -rw------- 1 root     2839 Jul 15  2022 model.py
# drwx------ 2 root     4096 Jan  7 14:05 __pycache__/
# -rw------- 1 root     2094 Jul 15  2022 README.md

# %%
# predict
import os
import pickle
import torch
import torch.nn.functional as F

device = torch.device("cuda")

def batchify(data, bsz):
    nbatch = data.size(0) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""
    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

def predict(input:str):
  # 设置seed和GPU环境


  # load id_mapping文件
  with open('./id_mapping.pkl', 'rb') as f:
    dic = pickle.load(f)

  # load模型
  with open('model.pt', 'rb') as f:
    model = torch.load(f)
    model.rnn.flatten_parameters()
    model.to(device)

  # 处理输入文本
  batch_size = 1
  text = input.split(" ")
  bptt = len(text)
  # 需要将未出现在词汇表中的词汇定义为<unk>
  text = [dic.word2idx[word] if word in dic.word2idx else dic.word2idx['<unk>'] for word in text]
  text_tensor = torch.tensor(text)

  data = batchify(text_tensor, batch_size)

  # 预测，并打印topN的词汇
  model.eval()
  hidden = model.init_hidden(batch_size)
  pred, hidden = model(data, hidden)
  pred = F.softmax(pred, dim=1)

  last_row = pred[-1, :]
  top_values, top_indices = torch.topk(last_row, k=10)
  pred = top_indices
  tensor_list = pred.tolist()
  for index in tensor_list:
    for key,value in dic.word2idx.items():
      if index == value:
        print(key)

input = "never too late to"
predict(input)
# Out:
# do
# be
# the
# make
# <unk>
# play
# reach
# use
# take
# have

# %% [markdown]
# ## glue-sst2 in LSTM

# %%
# 可以使用Tokenizer来处理文本
import torch
input = torch.randn(3, 5, requires_grad=True)
print(input)
# Out:
# tensor([[ 1.1418, -0.0427,  0.3615, -0.1207, -1.2194],
#         [-1.7356, -0.3106, -0.0264, -1.0470, -2.4602],
#         [-1.5302, -0.4010,  0.0132, -1.1681,  0.2779]], requires_grad=True)
